# %% [markdown]
# # テーマ：kickstarterが成功するか失敗するか分類したい

# %% [markdown]
# ## １．データ項目の説明

# %% [markdown]
# 初期状態について、ファンディング開始時に値が確定しているか未定化を表示

# %% [markdown]
# 項目名　| 意味 | 初期状態 | 目的変数
# -----------| ------------ | ------- | -----
# ID | kickstarterのID | 確定 |
# name| プロジェクト名称| 確定 |
# category | カテゴリ | 確定 |
# main_category | キャンペーンのカテゴリ | 確定 |
# currency | 通貨 | 確定 |
# deadline | クラウドファンディングの締め切り | 確定 |
# goal | 目標額（currency） | 確定 |
# launched | 発売日 | 確定 |
# pledged | 誓約額（currency） | 未定 |
# state | 現在のプロジェクト状態 | 未定 | 〇
# backers | 支援者の数 | 未定 |
# country | 国名（誓約） | 未定 |
# usd pledged | 誓約額（USD換算（KS)） | 未定 |
# usd_pledged_real | 誓約額（USD換算（fixer.io api)） | 未定 |
# usd_goal_real | 目標額（USD換算（fixer.io api)） | 確定 |

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
##CSVファイルを読み込みdataframeに変換
df_kick = pd.read_csv("./ks-projects-201801.csv")[['ID', 'name', 'category', 'main_category', 'currency', 'deadline', 'goal','launched','pledged','state','backers','country','usd pledged','usd_pledged_real','usd_goal_real']]

# %%
#〇目的変数はstateとして実施する
#目的変数を１，０に変換する、stateにはsuccessfulとfailed以外がある
#######successfulとfailed以外を除外した場合にどうなるか検討が必要
#df_kick['state'] = df_kick['state'] == 'successful'

#〇説明変数の中で区分などを変換する
#そのままではなく、相関関係や切り口を変えたものが結果に影響するものを新規列として追加する
#・クラウドファンディングの締め切りから発売日までの日数
#・プロジェクト名称の文字数
#・・・・・・？
#通貨の分類をダミー変数として追加、USD、GBP、その他に圧縮
df_kick.loc[~(df_kick.currency == 'USD') & (~(df_kick.currency == 'GBP')), 'currency'] = 'other'
df_kick_dummy=pd.get_dummies(df_kick.currency)
df_kick = pd.concat([df_kick, df_kick_dummy], axis=1)

#deadlineからlaunchedを引いた日数を新しい列（term）を追加
def f_str(x):
    return datetime.datetime.strptime(x, '%Y-%m-%d')
df_kick.deadline = df_kick.deadline.map(f_str)
def f_str(x):
    return datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
df_kick.launched = df_kick.launched.map(f_str)
df_kick["term"] = df_kick.deadline-df_kick.launched
def f_str(x):
    if x.days > 10000:
        return 0
    else:
        return x.days
df_kick["term_day"] = df_kick.term.map(f_str)

#プロジェクト名称の文字数で新しい列（name_len）を追加
def f_str(x):
    if type(x) is str:
        return len(x)
    else:
        return 0
df_kick["name_len"] = df_kick.name.map(f_str)

display(df_kick.head())

df_kick.describe()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline     goal  \
# 0          Poetry    Publishing      GBP 2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD 2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD 2013-02-26  45000.0
# 3           Music         Music      USD 2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD 2015-08-29  19500.0
#
#              launched  pledged     state    ...     country usd pledged  \
# 0 2015-08-11 12:12:28      0.0    failed    ...          GB         0.0
# 1 2017-09-02 04:43:57   2421.0    failed    ...          US       100.0
# 2 2013-01-12 00:20:50    220.0    failed    ...          US       220.0
# 3 2012-03-17 03:24:11      1.0    failed    ...          US         1.0
# 4 2015-07-04 08:35:03   1283.0  canceled    ...          US      1283.0
#
#    usd_pledged_real  usd_goal_real  GBP  USD  other             term term_day  \
# 0               0.0        1533.95    1    0      0 58 days 11:47:32       58
# 1            2421.0       30000.00    0    1      0 59 days 19:16:03       59
# 2             220.0       45000.00    0    1      0 44 days 23:39:10       44
# 3               1.0        5000.00    0    1      0 29 days 20:35:49       29
# 4            1283.0       19500.00    0    1      0 55 days 15:24:57       55
#
#    name_len
# 0        31
# 1        45
# 2        14
# 3        49
# 4        58
#
# [5 rows x 21 columns]
#                  ID          goal       pledged        backers   usd pledged  \
# count  3.786610e+05  3.786610e+05  3.786610e+05  378661.000000  3.748640e+05
# mean   1.074731e+09  4.908079e+04  9.682979e+03     105.617476  7.036729e+03
# std    6.190862e+08  1.183391e+06  9.563601e+04     907.185035  7.863975e+04
# min    5.971000e+03  1.000000e-02  0.000000e+00       0.000000  0.000000e+00
# 25%    5.382635e+08  2.000000e+03  3.000000e+01       2.000000  1.698000e+01
# 50%    1.075276e+09  5.200000e+03  6.200000e+02      12.000000  3.947200e+02
# 75%    1.610149e+09  1.600000e+04  4.076000e+03      56.000000  3.034090e+03
# max    2.147476e+09  1.000000e+08  2.033899e+07  219382.000000  2.033899e+07
#
#        usd_pledged_real  usd_goal_real            GBP            USD  \
# count      3.786610e+05   3.786610e+05  378661.000000  378661.000000
# mean       9.058924e+03   4.545440e+04       0.090139       0.780025
# std        9.097334e+04   1.152950e+06       0.286381       0.414230
# min        0.000000e+00   1.000000e-02       0.000000       0.000000
# 25%        3.100000e+01   2.000000e+03       0.000000       1.000000
# 50%        6.243300e+02   5.500000e+03       0.000000       1.000000
# 75%        4.050000e+03   1.550000e+04       0.000000       1.000000
# max        2.033899e+07   1.663614e+08       1.000000       1.000000
#
#                other                     term       term_day       name_len
# count  378661.000000                   378661  378661.000000  378661.000000
# mean        0.129836  33 days 21:58:10.533968      33.202807      34.834847
# std         0.336124  65 days 21:55:09.506515      12.793846      15.931822
# min         0.000000          0 days 00:07:17       0.000000       0.000000
# 25%         0.000000         29 days 02:20:36      29.000000      21.000000
# 50%         0.000000         29 days 16:32:32      29.000000      34.000000
# 75%         0.000000         36 days 15:35:44      36.000000      49.000000
# max         1.000000      16738 days 23:00:00      91.000000      96.000000

# %%
# 散布図を書いてみる 状況と目標額（USD換算（fixer.io api)）
plt.scatter(df_kick.state,df_kick.usd_goal_real)
plt.show()

# %%
# 箱ひげ図を書いてみる 状況と目標額（USD換算（fixer.io api)）
plt.boxplot(df_kick[df_kick.state=="successful"].usd_goal_real)
plt.show()

# %%
# 散布図を書いてみる 状況とプロジェクト名の文字数
plt.scatter(df_kick.state,df_kick.name_len)
plt.show()

# %%
# 散布図を書いてみる 状況と通貨の文字数
plt.scatter(df_kick.state,df_kick.currency)
plt.show()

# %%
# 散布図を書いてみる 状況と発売日と期限日数
plt.scatter(df_kick.state,df_kick.term_day)
plt.show()

# %%
# 散布図を書いてみる 状況とカテゴリー
plt.scatter(df_kick.state,df_kick.main_category)
plt.show()

# %%
# 散布図を書いてみる 状況と国
plt.scatter(df_kick.state,df_kick.country)
plt.show()

# %%
#null値が入っている行を調査
df_kick.isnull().sum()/df_kick.shape[0]
# Out:
# ID                  0.000000
# name                0.000011
# category            0.000000
# main_category       0.000000
# currency            0.000000
# deadline            0.000000
# goal                0.000000
# launched            0.000000
# pledged             0.000000
# state               0.000000
# backers             0.000000
# country             0.000000
# usd pledged         0.010027
# usd_pledged_real    0.000000
# usd_goal_real       0.000000
# GBP                 0.000000
# USD                 0.000000
# other               0.000000
# term                0.000000
# term_day            0.000000
# name_len            0.000000
# dtype: float64

# %%
#null値が入っている行を確認（name列にnull値が入っている場合に真）
df_kick[(df_kick['name'].isnull())]
# Out:
#                 ID name        category main_category currency   deadline  \
# 166851  1848699072  NaN  Narrative Film  Film & Video      USD 2012-02-29
# 307234   634871725  NaN     Video Games         Games      GBP 2013-01-06
# 309991   648853978  NaN  Product Design        Design      USD 2016-07-18
# 338931   796533179  NaN        Painting           Art      USD 2011-12-05
#
#             goal            launched  pledged      state    ...     country  \
# 166851  200000.0 2012-01-01 12:35:31    100.0     failed    ...          US
# 307234    2000.0 2012-12-19 23:57:48    196.0     failed    ...          GB
# 309991    2500.0 2016-06-18 05:01:47      0.0  suspended    ...          US
# 338931   35000.0 2011-11-06 23:55:55    220.0     failed    ...          US
#
#        usd pledged  usd_pledged_real  usd_goal_real  GBP  USD  other  \
# 166851      100.00            100.00      200000.00    0    1      0
# 307234      317.73            316.05        3224.97    1    0      0
# 309991        0.00              0.00        2500.00    0    1      0
# 338931      220.00            220.00       35000.00    0    1      0
#
#                    term term_day  name_len
# 166851 58 days 11:24:29       58         0
# 307234 17 days 00:02:12       17         0
# 309991 29 days 18:58:13       29         0
# 338931 28 days 00:04:05       28         0
#
# [4 rows x 21 columns]

# %%
df_kick.columns
# Out:
# Index(['ID', 'name', 'category', 'main_category', 'currency', 'deadline',
#        'goal', 'launched', 'pledged', 'state', 'backers', 'country',
#        'usd pledged', 'usd_pledged_real', 'usd_goal_real', 'GBP', 'USD',
#        'other', 'term', 'term_day', 'name_len'],
#       dtype='object')

# %%
sns.set_style('darkgrid')

mains = df_kick[df_kick.state=='successful'].main_category.value_counts().head(15)

x_suc = mains.values
y_suc = mains.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y_suc, x=x_suc, orient='h', palette="cool", alpha=0.8)

plt.title('Kickstarter Top 15 Category Count(sccessful)')
plt.show()

mains = df_kick[(df_kick.state=='failed')&(df_kick.main_category.isin(y_suc))].main_category.value_counts().head(15)

x_fail = mains.values
y_fail = mains.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y_fail, x=x_fail, orient='h', palette="cool", alpha=0.8)

plt.title('Kickstarter Top 15 Category Count(failed)')
plt.show()

# %%
print(x_suc)
print(y_suc)
# Out:
# [24197 23623 12518 12300 11510 10550  6534  6434  6085  5842  5593  3305
#   2338  2115  1012]
# Index(['Music', 'Film & Video', 'Games', 'Publishing', 'Art', 'Design',
#        'Theater', 'Technology', 'Food', 'Comics', 'Fashion', 'Photography',
#        'Dance', 'Crafts', 'Journalism'],
#       dtype='object')

# %%
# 凡例
label1 = 'y_suc'
label2 = 'y_fail'
# グラフの間隔
width = 0.3

# 棒グラフの描画
plt.bar(x=y_suc, height=x_suc, width=width, label=label1)
plt.bar(x=y_fail, height=x_fail, width=width, label=label2)

# 軸を移動
#plt.xticks(x_suc + width/2, x_suc)

# x軸，y軸のラベルを設定
plt.xlabel('x')
#plt.ylabel('y')

# 凡例を表示
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.show()

# %%
sns.set_style('darkgrid')
mains = df_kick.main_category.value_counts().head(15)

x = mains.values
y = mains.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="cool", alpha=0.8)

plt.title('Kickstarter Top 15 Category Count')
plt.show()

mains = df_kick[df_kick.state=='successful'].main_category.value_counts().head(15)

x = mains.values
y = mains.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="cool", alpha=0.8)

plt.title('Kickstarter Top 15 Category Count(sccessful)')
plt.show()

mains = df_kick[df_kick.state=='failed'].main_category.value_counts().head(15)

x = mains.values
y = mains.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="cool", alpha=0.8)

plt.title('Kickstarter Top 15 Category Count(failed)')
plt.show()

# %%
cats = df_kick.category.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 Sub-Category Count')
plt.show()

cats = df_kick[df_kick.state=='successful'].category.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 Sub-Category Count(successful)')
plt.show()

cats = df_kick[df_kick.state=='failed'].category.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 Sub-Category Count(failed)')
plt.show()

# %%
cats = df_kick.name_len.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 name_len Count')
plt.show()

cats = df_kick[df_kick.state=='successful'].name_len.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 name_len Count(successful)')
plt.show()

cats = df_kick[df_kick.state=='failed'].name_len.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 name_len Count(failed)')
plt.show()

# %%
cats = df_kick.term_day.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 term_day Count')
plt.show()

cats = df_kick[df_kick.state=='successful'].term_day.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 term_day Count(successful)')
plt.show()

cats = df_kick[df_kick.state=='failed'].term_day.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 term_day Count(failed)')
plt.show()

# %%
cats = df_kick.currency.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 currency Count')
plt.show()

cats = df_kick[df_kick.state=='successful'].currency.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 currency Count(successful)')
plt.show()

cats = df_kick[df_kick.state=='failed'].currency.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 currency Count(failed)')
plt.show()

# %%
cats = df_kick.currency.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 currency Count')
plt.show()

cats = df_kick[df_kick.state=='successful'].currency.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 currency Count(successful)')
plt.show()

cats = df_kick[df_kick.state=='failed'].currency.value_counts().head(15)

x = cats.values
y = cats.index

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111)
ax = sns.barplot(y=y, x=x, orient='h', palette="winter", alpha=0.8)

plt.title('Kickstarter Top 15 currency Count(failed)')
plt.show()

# %%
(df_kick.deadline-df_kick.launched).dt.days.value_counts().head(15)
# Out:
# 29    169171
# 59     33623
# 44     17749
# 30     13261
# 34     10099
# 39     10039
# 31      7294
# 19      6831
# 20      6716
# 28      6192
# 24      6139
# 32      5775
# 27      5466
# 14      5379
# 13      4176
# dtype: int64

# %%
#df_kick['log_usd_per_backer'] = np.log(df_kick['usd pledged']/df_kick['backers'])
#df_kick['log_goal_per_backer'] = np.log(df_kick['goal']/df_kick['backers'])
# Out:
# C:\Users\oanc2fs1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
#backersに0が入っている行　かつ　stateがsuccessfulの行を確認
#df_kick[(df_kick.backers==0)&(df_kick.state=='successful')]
df_kick[(df_kick.backers==0)&(df_kick.state==True)]
# Out:
#                 ID                                               name  \
# 2457    1012744036          An Oratorio for our Time - Last Stop Cafe
# 4892    1024989802                   Jackson Ruby: The Cassette Album
# 5353    1027275369        Help Parker Brown make his first solo album
# 5597    1028691308          Help BETHANY record a NEW single in Nash!
# 8260    1041708793       Serena Gabriel's first CD!!!!!!: Diving Deep
# 13001   1065249597  SCiO: Your Sixth Sense. A Pocket Molecular Sen...
# 13048   1065509232                                 LUME Festival 2016
# 14527   1073104639                              SUNN - EP - Pre-vente
# 16769   1084993156  Willy Tea, Chris Doud and Chums: The Children'...
# 21385    110837091                                      Nathan Menard
# 23172   1117631926        Jesse Henry's Desert Songwriting Sabbatical
# 25975   1131956331      Porter Band "Make Jesus Famous" Album Support
# 32500   1165084901           School for Classics Songwriting Workshop
# 44765   1227315610                                        SourKoolaid
# 44910   1228019792                                 Rock the Farmagain
# 46952   1238892978  kopascetic - Ryan David Orr's 6th full-length ...
# 51084   1260197823                                      FUR debut LP!
# 54017   1274904332             The Innocent Men Full-Length Album ~i~
# 62375   1317117360    It's time for my 1st EP - and I need your help!
# 64114     13260497                    WALKING: THE WISDOM OF THE ROAD
# 68730   1349873935                       Something Wild Film Festival
# 72052   1366813820               Ingrid Halle- Release of Debut Album
# 74500   1379649454  Juiette Z. Payne presents debut EP "Eternal Da...
# 74521   1379755099                        God as she makes this earth
# 77862    139596297  Southern Skies Album Pre-release Fundraiser - ...
# 84653   1430463866            Chase McBride - New Album & Music Video
# 100985  1512908710           Join Tim Snider in making his new album!
# 105422  1535815142  Help Fund The Dipping Skinnies First Full Leng...
# 108132  1549719796                              Made in Kibera Studio
# 111081  1564395726   A Christmas Album made by the Pure Witness Band!
# ...            ...                                                ...
# 293938   566129955                                        Edgar Allan
# 294483   568777516   'Southern Writer' - a new Record by Brian Pounds
# 295359   573365912                                       Truth BeTold
# 296166   577662386                                Kyle LaLone Solo EP
# 302443   610154753              'MIA 2 LAX' The Track Burnaz Debut EP
# 302638   611083586              Flannel Graph - The People We Were EP
# 303950   617632903                          Cali Wilson: The First EP
# 306016   628318669                        Meekoh // Fire and Diamonds
# 307143   634327860        "To New Beginnings" CD fund & My Heart Tour
# 309369   645829934                       IFs... a new album from 'UNA
# 314157   670047018                              Wonderland, The Album
# 317191   685752214               Tizmoret's 20th Year Album : "Score"
# 74521  2016-04-19 16:33:50     2153.00   True    ...        N,0"         NaN
# 77862  2016-03-31 18:26:06     4196.00   True    ...        N,0"         NaN
# 84653  2013-03-12 19:06:29     4961.00   True    ...        N,0"         NaN
# 100985 2013-03-08 18:36:41     7318.00   True    ...        N,0"         NaN
# 105422 2016-04-13 22:47:09     1508.00   True    ...        N,0"         NaN
# 108132 2016-04-26 20:23:40     4658.30   True    ...        N,0"         NaN
# 111081 2016-03-18 01:06:46     4010.00   True    ...        N,0"         NaN
# ...                    ...         ...    ...    ...         ...         ...
# 293938 2016-04-04 20:28:46     3425.00   True    ...        N,0"         NaN
# 294483 2016-04-15 18:15:18     8525.00   True    ...        N,0"         NaN
# 295359 2016-04-12 12:56:11     2011.00   True    ...        N,0"         NaN
# 296166 2016-04-12 05:11:40     3070.00   True    ...        N,0"         NaN
# 302443 2016-04-08 10:07:43     2452.00   True    ...        N,0"         NaN
# 302638 2016-05-07 01:06:02     5668.00   True    ...        N,0"         NaN
# 303950 2016-03-04 01:26:26     5810.00   True    ...        N,0"         NaN
# 306016 2016-05-03 02:43:13     4161.00   True    ...        N,0"         NaN
# 307143 2016-03-02 22:39:12     7286.00   True    ...        N,0"         NaN
# 309369 2016-04-19 15:04:19     3129.00   True    ...        N,0"         NaN
# 314157 2016-04-05 11:56:16     2311.00   True    ...        N,0"         NaN
# 317191 2016-05-02 04:07:09     5427.00   True    ...        N,0"         NaN
# 318239 2013-03-08 15:14:22     3185.00   True    ...        N,0"         NaN
# 318556 2016-04-18 05:14:27     2186.00   True    ...        N,0"         NaN
# 318781 2016-04-12 06:12:25     1670.00   True    ...        N,0"         NaN
# 323142 2016-04-30 20:00:00     2060.00   True    ...        N,0"         NaN
# 324209 2016-04-21 05:30:46     6525.60   True    ...        N,0"         NaN
# 324571 2016-03-30 20:14:45     8025.00   True    ...        N,0"         NaN
# 338430 2016-03-25 06:44:28     5514.00   True    ...        N,0"         NaN
# 341257 2016-05-20 21:01:56     4497.00   True    ...        N,0"         NaN
# 344315 2016-04-07 23:24:41     5955.00   True    ...        N,0"         NaN
# 344755 2016-04-12 19:21:59     1500.00   True    ...        N,0"         NaN
# 348821 2016-04-07 15:35:33     7623.00   True    ...        N,0"         NaN
# 350302 2016-03-17 20:04:13     8889.00   True    ...        N,0"         NaN
# 360465 2016-05-01 19:40:30     3646.00   True    ...        N,0"         NaN
# 367884 2013-03-12 20:03:33     2780.00   True    ...        N,0"         NaN
# 368641 2016-03-30 17:23:28     2560.00   True    ...        N,0"         NaN
# 368860 2016-03-25 03:54:04     9625.00   True    ...        N,0"         NaN
# 372375 2016-04-05 18:56:21     3686.00   True    ...        N,0"         NaN
# 378188 2016-04-14 01:27:27     2300.00   True    ...        N,0"         NaN
#
#         usd_pledged_real  usd_goal_real  GBP  USD  other             term  \
# 2457             5170.00        5000.00    0    1      0 29 days 04:13:34
# 4892             5296.00        5000.00    0    1      0 29 days 04:30:43
# 5353             5077.00        3800.00    0    1      0 29 days 07:45:32
# 344755           1500.00        1500.00    0    1      0 29 days 04:38:01
# 348821           7623.00        7500.00    0    1      0 34 days 08:24:27
# 350302           8889.00        6500.00    0    1      0 39 days 03:55:47
# 360465           3646.00        3500.00    0    1      0 29 days 04:19:30
# 367884           2780.00        2500.00    0    1      0 29 days 03:56:27
# 368641           2560.00        2500.00    0    1      0 29 days 06:36:32
# 368860           9625.00        8000.00    0    1      0 59 days 20:05:56
# 372375           3686.00        3500.00    0    1      0 22 days 05:03:39
# 378188           2300.00        2000.00    0    1      0 29 days 22:32:33
#
#        term_day  name_len
# 2457         29        41
# 4892         29        32
# 5353         29        43
# 5597         33        41
# 8260         36        44
# 13001        46        59
# 13048        30        18
# 14527        39        21
# 16769        13        53
# 21385        39        13
# 23172        14        43
# 25975        29        45
# 32500        29        40
# 44765        29        11
# 44910        27        18
# 46952        24        51
# 51084        20        13
# 54017        47        38
# 62375        29        47
# 64114        38        31
# 68730        34        28
# 72052        29        36
# 74500        39        51
# 74521        29        27
# 77862        32        59
# 84653        29        39
# 100985       29        40
# 105422       44        54
# 108132       29        21
# 111081       50        48
# ...         ...       ...
# 293938       24        11
# 294483       34        48
# 295359       29        12
# 296166       29        19
# 302443       29        37
# 302638       17        37
# 303950       59        25
# 306016       14        27
# 307143       59        43
# 309369       29        28
# 314157       29        21
# 317191       28        36
# 318239       29        31
# 318556       31        49
# 318781       15        56
# 323142       29        52
# 324209       29        43
# 324571       29        56
# 338430       30        60
# 341257        7        35
# 344315       29        32
# 344755       29        15
# 348821       34        28
# 350302       39        50
# 360465       29        40
# 367884       29        59
# 368641       29        45
# 368860       59        59
# 372375       22        38
# 378188       29        42
#
# [105 rows x 21 columns]

# %%
#0が入っている行のstateを確認
df_kick[(df_kick.backers==0)].state.value_counts()
# Out:
# False    55504
# True       105
# Name: state, dtype: int64

# %%
#df_kick_v2 = df_kick[(df_kick.backers!=0)|(df_kick.state!='successful')]
df_kick_v2 = df_kick[(df_kick.backers!=0)|(df_kick.state!=True)]

# %%
#0が入っている行のstateを確認
df_kick_v2[(df_kick_v2.backers==0)].state.value_counts()
# Out:
# False    55504
# Name: state, dtype: int64

# %%
df_kick.state.value_counts()
# Out:
# False    244705
# True     133956
# Name: state, dtype: int64

# %%
df_kick_v2.state.value_counts()
# Out:
# False    244705
# True     133851
# Name: state, dtype: int64

# %%
 df_kick[(df_kick.state==True)].name_len.value_counts().head(10)
# Out:
# 60    4976
# 59    3857
# 58    3222
# 57    3056
# 56    2997
# 32    2722
# 55    2714
# 30    2680
# 31    2676
# 54    2632
# Name: name_len, dtype: int64

# %%
 df_kick[(df_kick.state==False)].name_len.value_counts().head(10)
# Out:
# 60    8444
# 59    6158
# 58    5590
# 20    5535
# 19    5351
# 18    5299
# 21    5268
# 17    5227
# 22    5207
# 16    5195
# Name: name_len, dtype: int64

# %%
cats_succ = df_kick[(df_kick.state=='successful')].category.value_counts()
cats_fail = df_kick[(df_kick.state=='failed')].category.value_counts()
#カテゴリ毎の成功割合で新しい列（category_succ_rate）を追加
def f_str(x):
    if type(x) is str:
        return cats_succ[x]/(cats_succ[x]+cats_fail[x])
    else:
        return 0
df_kick["category_succ_rate"] = df_kick.category.map(f_str)

cats_succ = df_kick[(df_kick.state=='successful')].main_category.value_counts()
cats_fail = df_kick[(df_kick.state=='failed')].main_category.value_counts()
#カテゴリ毎の成功割合で新しい列（category_succ_rate）を追加
def f_str(x):
    if type(x) is str:
        return cats_succ[x]/(cats_succ[x]+cats_fail[x])
    else:
        return 0
df_kick["main_category_succ_rate"] = df_kick.main_category.map(f_str)

# %%
cats_succ = df_kick[(df_kick.state=='successful')].category.value_counts()
cats_fail = df_kick[(df_kick.state=='failed')].category.value_counts()
print(cats_succ['Music']/(cats_succ['Music']+cats_fail['Music']))
# Out:
# 0.5091427214438375

# %%
display(df_kick[df_kick.category=='Music'])
# Out:
#                 ID                                               name  \
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 18      1000070642                Mike Corey's Darkness & Light Album
# 25      1000102741  Matt Cavenaugh & Jenny Powers make their 1st a...
# 34       100012079            Chris Eger Band - New Nashville Record!
# 41      1000153208    Phil Younger - Slow Down (Official Music Video)
# 89      1000344383  ¿Tu Sabes? (You Know?) a music collaboration b...
# 160      100065084     One Man's Opinion Of Moonlight Song Collection
# 172     1000707541                      Elephant Gun Media Blitzkrieg
# 182     1000758916        Keys to the Moon's First Full Length Album!
# 294     1001303993                        A Jessica Rabbit Production
# 328      100149523                        Duncan Woods - Chameleon EP
# 351     1001576108                                     Light Comes In
# 395     1001842762        Gospel Jazz Independant Artist - CD Project
# 529     1002554777                    A Better Morrissey Birthday Mix
# 532     1002571103                         3mm Aluminum Pick Plectrum
# 541     1002617687                                      OPEN The TANK
# 550     1002651584                   the mailboxes forthcoming album!
# 560     1002720451                Stage one & Stage two Music theatre
# 578     1002780789        Nabil & Karim | Anise K ~ Bicentenary Album
# 594     1002864290                          Winter in Mind EP Funding
# 596     1002877175   Charlene Kaye makes a new record - "Animal Love"
# 604     1002907198                                            WazUpio
# 626     1002997533                Pony Death Ride is making an album!
# 629      100301303                    Love Animals - Debut EP Project
# 632     1003023003          The Making of Ashley Kelley's Debut Album
# 641     1003104071                                 One GuitarMan Band
# 647     1003130892                       Butter Side Down Debut Album
# 650     1003155427  Philip & Brittany Burton - NEW ALBUM - Nothing...
# 659     1003216930     Calvin Thomas: Making the "October Sky" Album!
# 664     1003240719                        Boutique Disco Flash Québec
# ...            ...                                                ...
# 378104   997401687                         The Good Fiction Recording
# 378123   997468532         J.R. Locke records his debut EP, "Take Me"
# 378124   997478323      Michael Bernier & Ritchie DeCarlo First Album
# 378138    99754004                                             Aporia
# 378142   997554968  Susan Picking: Making Music with Kids in the S...
# 378182   997778065                     My First Official Studio Album
# 378194   997812012                            KOSENT Music Group Tour
# 378205   997858609               LAST SEPTEMBER Musical WAC recording
# 378219   997915422                    Otter's First Full Length Album
# 378250   998079196                  Kaleigh Baker's Full Length Album
# 378277   998228187                      CampStock Music Festival 2012
# 378322   998401361  Support Tiffany Monìque's New Video & Single! ...
# 596           29        48           0.509143                 0.526606
# 604           23         7           0.509143                 0.526606
# 626           32        35           0.509143                 0.526606
# 629           29        31           0.509143                 0.526606
# 632           29        41           0.509143                 0.526606
# 641           29        18           0.509143                 0.526606
# 647           23        28           0.509143                 0.526606
# 650           31        54           0.509143                 0.526606
# 659           44        46           0.509143                 0.526606
# 664           55        27           0.509143                 0.526606
# ...          ...       ...                ...                      ...
# 378104        20        26           0.509143                 0.526606
# 378123        10        42           0.509143                 0.526606
# 378124        15        45           0.509143                 0.526606
# 378138        21         6           0.509143                 0.526606
# 378142        28        59           0.509143                 0.526606
# 378182        14        30           0.509143                 0.526606
# 378194        60        23           0.509143                 0.526606
# 378205        49        36           0.509143                 0.526606
# 378219        29        31           0.509143                 0.526606
# 378250        29        33           0.509143                 0.526606
# 378277        59        29           0.509143                 0.526606
# 378322        60        56           0.509143                 0.526606
# 378367        59        59           0.509143                 0.526606
# 378375        29        37           0.509143                 0.526606
# 378378        29        53           0.509143                 0.526606
# 378400        56        48           0.509143                 0.526606
# 378409        29        58           0.509143                 0.526606
# 378428        59        14           0.509143                 0.526606
# 378434        29        22           0.509143                 0.526606
# 378435        45        51           0.509143                 0.526606
# 378447        20        52           0.509143                 0.526606
# 378469        29        38           0.509143                 0.526606
# 378471        44        37           0.509143                 0.526606
# 378477         9        50           0.509143                 0.526606
# 378496        44        19           0.509143                 0.526606
# 378547        44        49           0.509143                 0.526606
# 378552        89        54           0.509143                 0.526606
# 378572        34        25           0.509143                 0.526606
# 378585        27        46           0.509143                 0.526606
# 378596        24        55           0.509143                 0.526606
#
# [15727 rows x 23 columns]

# %%
cats_succ = df_kick[(df_kick.state=='successful')].main_category.value_counts()
cats_fail = df_kick[(df_kick.state=='failed')].main_category.value_counts()
print(cats_succ['Music']/(cats_succ['Music']+cats_fail['Music']))
# Out:
# 0.5266055844523276

# %%
display(df_kick.head())
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline     goal  \
# 0          Poetry    Publishing      GBP 2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD 2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD 2013-02-26  45000.0
# 3           Music         Music      USD 2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD 2015-08-29  19500.0
#
#              launched  pledged     state           ...             \
# 0 2015-08-11 12:12:28      0.0    failed           ...
# 1 2017-09-02 04:43:57   2421.0    failed           ...
# 2 2013-01-12 00:20:50    220.0    failed           ...
# 3 2012-03-17 03:24:11      1.0    failed           ...
# 4 2015-07-04 08:35:03   1283.0  canceled           ...
#
#    usd_pledged_real usd_goal_real  GBP  USD  other             term  term_day  \
# 0               0.0       1533.95    1    0      0 58 days 11:47:32        58
# 1            2421.0      30000.00    0    1      0 59 days 19:16:03        59
# 2             220.0      45000.00    0    1      0 44 days 23:39:10        44
# 3               1.0       5000.00    0    1      0 29 days 20:35:49        29
# 4            1283.0      19500.00    0    1      0 55 days 15:24:57        55
#
#    name_len category_succ_rate  main_category_succ_rate
# 0        31           0.390851                 0.347017
# 1        45           0.435903                 0.417906
# 2        14           0.435903                 0.417906
# 3        49           0.509143                 0.526606
# 4        58           0.355983                 0.417906
#
# [5 rows x 23 columns]
